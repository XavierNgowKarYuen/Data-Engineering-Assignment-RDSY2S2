# %% [markdown]
# <a href="https://colab.research.google.com/github/Brynlai/Data-Engineering-Assignment-RDSY2S2/blob/Alia/comments_scraping_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import requests
from bs4 import BeautifulSoup

# Class to represent a Scraped Comment
class Comment:
   def __init__(self, comment_id, user, comment_text):
     self.comment_id = comment_id
     self.user = user
     self.comment_text = comment_text

   def __str__(self):
      return f"""
      Comment ID: {self.comment_id}
      User: {self.user}
      Comment:
      {self.comment_text}
      """

# Class to hold scraped data
class ScrapedData:
  def __init__(self, aid, title, date, publisher, views, comments_count, content, comments):
    self.aid = aid
    self.title = title
    self.date = date
    self.publisher = publisher
    self.views = views
    self.comments_count = comments_count
    self.content = content
    self.comments = comments


  # String representation of the object
  def __str__(self):
      comments_str = "\n".join(str(comment) for comment in self.comments)
      return f"""
      Aid: {self.aid}
      Title: {self.title}
      Date: {self.date}
      Publisher: {self.publisher}
      Views: {self.views}
      Comments Count: {self.comments_count}
      Content:
      {self.content}
      Comments Section:
      {comments_str}
        """

# Function to scrape all comments
def scrape_comments(soup):
    comments = []  # List to store all comments

    # Locate the comments container
    comments_container = soup.find('div', id='comment_ul')
    if not comments_container:
        return comments

    # Find all <dl> or <dI> tags inside the container
    comment_tags = comments_container.find_all(['dl', 'dI'], id=True)

    for comment_tag in comment_tags:
        # Extract unique comment ID
        comment_id = comment_tag.get('id').replace('comment_', '').split('_')[0]

        # Extract username
        user_tag = comment_tag.find('a', class_='xi2')
        user = user_tag.text.strip() if user_tag else "Anonymous"

        # Extract the comment text
        comment_text_tag = comment_tag.find('dd')
        if comment_text_tag:
            # Remove quote
            quote_tags = comment_text_tag.find_all('div', class_='quote')
            for quote_tag in quote_tags:
                quote_tag.extract()

            # Get the cleaned text
            comment_text = comment_text_tag.get_text(strip=True)
        else:
            comment_text = "No comment text"

        # Append the extracted comment to the list
        comments.append(Comment(comment_id=comment_id, user=user, comment_text=comment_text))

    return comments

# Scrape article from URL and aid
def scrape_article(url, aid):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract title
    title = soup.find('title').text

    # Extract date
    date_tag = soup.find('p', class_='xg1')
    date = date_tag.text.split('|')[0].strip() if date_tag else "Unknown"

    # Extract publisher
    publisher_tag = date_tag.find('a') if date_tag else None
    publisher = publisher_tag.text if publisher_tag else "Unknown"

    # Extract views
    views_tag = soup.find('em', id='_viewnum')
    views = views_tag.text if views_tag else "0"

    # Extract comments count
    comments_tag = soup.find('em', id='_commentnum')
    comments_count = comments_tag.text if comments_tag else "0"

    # Extract content
    content_tag = soup.find('td', id='article_content')
    content = content_tag.get_text(strip=True) if content_tag else ""

    # Extract comments
    comments = scrape_comments(soup)

    return ScrapedData(aid, title, date, publisher, views, comments_count, content, comments)

# Main function to orchestrate scraping process
def main():
    base_url = "https://b.cari.com.my/portal.php?mod=view&aid="

    # List of aids to scrape
    aid_values = list(range(1,6))  # Should be until 25000+
    aid_values.append(20000) # Because AID is sequential.

    for aid in aid_values:
        url = f"{base_url}{aid}"   # Construct full URL

        try:
            scraped_data = scrape_article(url, aid)   # Scrape data

            print(scraped_data)                         # Print data

            print("\n------------------------\n")       # Print separator

        except Exception as e:
            print(f"Error scraping {url}: {e}")       # Handle exceptions

if __name__ == "__main__":
    main()                                           # Run main function
# Out:
#       Aid: 1
#       Title: Laporan polis terhadap Uncle Seekers didakwa hina Sultan Johor - CariDotMy
#       Date: 19-7-2012 05:16 PM
#       Publisher: cmcadmin
#       Views: 243700
#       Comments Count: 1917
#       Content:
#       Post Last Edit by the_killer at 1-7-2012 17:14JOHOR BAHARU 1 Julai - Tiga puluh individu hari ini membuat laporan polis terhadap pengamal paranormal Syed Abdullah Hussein Al-Attas atau lebih dikenali sebagai Uncle Seekers berhubung penyiaran artikel dalam blognya yang dikatakan berunsur provokasi, hasutan dan mengaibkan Sultan Johor.Laporan polis berkenaan dibuat pada pukul 12.10 tengah hari di Balai Polis Sentral, di sini, bagi memohon pihak berkuasa menjalankan siasatan terhadap blog uncleseekers.blogspot.com yang turut berunsur mengaibkan Tunku Mahkota Johor, pemimpin dan penjawat awam kerajaan Johor.Wakil kesemua individu berkenaan, seorang peniaga, Khairil Azlishah Jalil, 32, ketika ditemui pemberita berkata pihaknya meminta blog berkenaan ditutup memandangkan terdapat dokumen-dokumen sulit yang dipaparkan pada blog tersebut."Sebagai rakyat Johor yang taat setia kepada Duli Yang Maha Mulia Sultan Johor Sultan Ibrahim dan kerajaan berperlembagaan, kami tidak puas hati dengan dakwaan-dakwaan serta hasutan yang boleh memecah belahkan rakyat Johor dan kesejahteraan negeri ini."Kami tidak mewakili mana-mana parti atau badan bukan kerajaan. Kami dapati penulisan di dalam blog berkenaan semakin hari semakin menjadi-jadi dan sehubungan itu kami mahu polis menjalankan siasatan mengenainya," katanya.http://www.utusan.com.my/utusan/info.asp?y=2012&dt=0701&pub=Utusan_Malaysia&sec=Dalam_Negeri&pg=dn_23.htmhttp://uncleseekers.blogspot.com/
#       Comments Section:
#
#       Comment ID: 49461174
#       User: solstice
#       Comment:
#       Org yg buat jenayah x kenaOrg yg mndedahkan pulopp yg kenaMoga tuhan menghinakan mereka2 yg brkenaan sehina2nya
#
#
#       Comment ID: 49461177
#       User: sekngucing
#       Comment:
#       kah kah kah, itu diaaaaaaaaaaaaaaaaaa
#
#
#       Comment ID: 49461181
#       User: ~anya~
#       Comment:
#       datuk Z bila nak kena dakwa pulak?
#
#
#       Comment ID: 49461209
#       User: MissNigga
#       Comment:
#       Bila nak siasat saya?he..he..Siot jer ankle seeker nie
#
#
#       Comment ID: 49461261
#       User: ifanonline
#       Comment:
#       adakah forumer unspekted tu yg buat laporan? katanya brassball kulop?
#
#
#       Comment ID: 49461343
#       User: zaianim
#       Comment:
#       kalau lah benda2 yg didedahkan itu memang fakta. adakah Uncle Seekers di pihak yg salah??
#
#
#       Comment ID: 49461355
#       User: RedDevils
#       Comment:
#       Syed Abdullah Hussein Al-Attas -tu sebab dia selamba menulis
#
#
#       Comment ID: 49461357
#       User: peachRose
#       Comment:
#       sbb keturunan Al Attas ker?
#
#
#       Comment ID: 49461511
#       User: batmana
#       Comment:
#       byk sgt bukti didedahkn..kalu report polis pun makin teruk plak sultan yg kene..bukan imuniti sultan dlm mahkamah dh takde ke..so, yg report tu kire saje nk kenakan sultan sbnrnya...
#
#
#       Comments Section:
#
#       Comment ID: 49615498
#       User: makadek
#       Comment:
#       Tak payah tanya.dh wamai bini ngadu kat bod fnd laki wart derkkk..je.....tu maksudnya aper
#
#
#       Comment ID: 49615580
#       User: bzzts
#       Comment:
#       kalo somi tak ajak, bini la mintak! tu pun payah ke?
#
#
#       Comment ID: 49615690
#       User: rafiacmilan
#       Comment:
#       stuju ngn ko..tu la ego pmpn..tggu kta je mtk..
#
#
#       Comment ID: 49615770
#       User: makadek
#       Comment:
#       Huh malas...wat per mintak2...lagi tggi ego.lagi baik sebis.yg bakal diterima kekekek
#
#
#       Comment ID: 49616506
#       User: jjenabmatpau
#       Comment:
#       Masaalahnyer, dah mintak tapi still buat-buat tak tau... Mau tak meroyan aku dibuatnye, mulalah syak yang bukan-bukan...
#
#
#       Comment ID: 49617072
#       User: feleesha91
#       Comment:
#       tak kesah pn...kne fhm suami gk..pnt2 keje..bg la pluang dia rht..
#
#
#       Comment ID: 49617133
#       User: cherylrihanna
#       Comment:
#       seminggu? sehari pon dah menggelupur kot..
#
#
#       Comment ID: 49617249
#       User: bzzts
#       Comment:
#       pepandai la ngorat, seduce, goda... laki sndiri, flirt la kaw2.omputeh lam tv slalu duk promote "date night", lakibini siap cari baby sitter, upah utk jaga anak2 smentara diorg gi deting. utk apa? eratkan kaseh sayang la... benda ni bagus, tapi taktau org malaysia ade tiru benda ni ke tidak...
#
#
#       Comment ID: 49617259
#       User: bzzts
#       Comment:
#       Reply4#rafiacmilantu la, tiba2 je jadi "lelaki je yg mintak"... kan? lelaki je la yg kuat nafsu.padehal bini yg memalu miaw...time becinte dulu pandai majuk sakan... mintak pujuk...
#
#
#       Comment ID: 49617327
#       User: koba
#       Comment:
#       ini mesti dah lame kawen niyang tt plak, mesti jenis baru kawen. tu yg saspek semacam tu
#
#
#       Comment ID: 49618061
#       User: winsonyu
#       Comment:
#       sehari pon dah menggelupur??? wah3..
#
#
#       Comment ID: 49618622
#       User: kurmasafia
#       Comment:
#       tak penah la plak jd mcm tu...tak sampai seminggu dh mintak..4hari pling maximum...kalu aku period seminggu mmg dia tak mintak la...so, menjawab soklan tak?ala, kalu laki tak mintak, bini mintakla...dapat pahala perang tau....
#
#
#       Comment ID: 49618700
#       User: ctaz
#       Comment:
#       ala aku biasa jer....mintak bini aku sminggu skali....tak do apa2 yg pelik pun...lain ler yg baru kawin tu.....hari2mau......HAR
#
#
#       Comment ID: 49618761
#       User: epysha
#       Comment:
#       perlu ke nak berperasaan apa2??
#
#
#       Comment ID: 49619107
#       User: lala_mily
#       Comment:
#       somi x mintak.... istri ler kena pandai goda somi. xkan main terjah jerr. kang xpandai goda,layan somi.... jalang2 kat luar tu nak jer layan2 laki xkira somi org @ tdk.
#
#
#       Comment ID: 49619722
#       User: secretmama
#       Comment:
#       kalau me, lagi best hapa, dapat rehat....penat woooo....Nak-nak dah ada anak, keja lagi....tido lagi best....hehehe.
#
#
#       Comment ID: 49620317
#       User: dani_5353
#       Comment:
#       Aku kalau tak dapat lebih dari dua hari...mula lah nak stress....
#
#
#       Comment ID: 49620410
#
#
#       Comment ID: 49669807
#       User: ruzaimah
#       Comment:
#       Reply17#AbukRokokHAAH..YG NI MMG ADA...Mulut dorg sush nk ckp mtk maaf..tp bila die mula brckp baik dgn kite, rapat2 ngn kita, nmpkla kat ctu yg dorg sbrnye nk berbaik dgn kite...tp ada gak pompuan xmo mcm tu..nk jgk kluar maaf dr lelaki tu...
#
#
#
# ------------------------
#
#
#       Aid: 20000
#       Title: Doktor Disimbah Petrol Oleh Pesakit - CariDotMy
#       Date: 18-6-2015 11:14 AM
#       Publisher: CMFreporter2
#       Views: 5067
#       Comments Count: 13
#       Content:
#       Oleh Adib ZaMimpi indah menjadi ngeri apabila seorang doktor di Guangxi, China terbakar dan melecur sekurang-kurangnya 30 peratus daripada badannya.Akibat tidak dapat menahan rasa marah, seorang pesakit telah menyimbah doktor tersebut dengan petrol sebelum membakarnya.Menurut laporan Shanghaiist, insiden tersebut berlaku pada 8.40 pagi apabila seorang pesakit kanser berusia 37 tahun membaca sebotol kecil petrol dan menyimbah ke arah seorang doktor.Laporan polis telah dibuat dan suspek ditangkap sejurus polis tiba di tempat kejadian.(Sumber foto: Shanghaiist)Insiden serangan terhadap pekerja hospital bukan sesuatu yang baru di China. Terbaru pada Mei, tiga orang doktor di Shanghai telah tercedera akibat dikelar pisau oleh seorang pesakit.- CARI Infonet
#       Comments Section:
#
#       Comment ID: 59966318
#       User: spiderman80
#       Comment:
#       China lagi... ok,next.
#
#
#       Comment ID: 59966400
#       User: chinta89
#       Comment:
#       Salah seorang pakar berkata, kebayakan konflik pesakit dan doktor biasanya melibatkan pakar ortopedik, ginekologi dan obstetrik.kenapa pakar2 ni je yg selalu jd mangsa?? why bother why bother?
#
#
#       Comment ID: 59966455
#       User: supernaturalee
#       Comment:
#       die yg sakit, doktor yg jd mangsakronik kes kot, xleh terima
#
#
#       Comment ID: 59966502
#       User: chinta89
#       Comment:
#       pelik2 ummah cina ni kan.. doc lak jd mangsa...
#
#
#       Comment ID: 59966504
#       User: bellaa
#       Comment:
#       sendiri sakit.. nak marah doc pulak
#
#
#       Comment ID: 59966508
#       User: gekkou
#       Comment:
#       kes tak boleh terima penyakit yang tinggal masa nk mati jek kotkesian doktorpakar plak tu
#
#
#       Comment ID: 59966535
#       User: zameyla
#       Comment:
#       bertabahlah doctor....
#
#
#       Comment ID: 59966585
#       User: CrowneGlory
#       Comment:
#       Ummah china, doc china... Siapa yg salah... Jgn doc tersilap diagnose selayaknya kena simbah
#
#
#       Comment ID: 59966606
#       User: Mary_jane
#       Comment:
#       Sakit kanser & dapat pakej sakit jiwa. Kesian doktor jadi mangsa.
#
#
#       Comment ID: 59966640
#       User: crazecousa
#       Comment:
#       perghhh jadik doktor pakar pun susah rupenye kt china
#
#
#       Comment ID: 59966785
#       User: Felycya
#       Comment:
#       Doktor menyelamatkan orangTp doktor itu sendiri xselamat.
#
#
#       Comment ID: 59968302
#       User: Pooriang
#       Comment:
#       ptot kne wat pade doktor yg jahat
#
#
#
# ------------------------
